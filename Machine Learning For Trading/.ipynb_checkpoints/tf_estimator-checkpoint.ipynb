# %% [markdown]
# # Tensorflow Estimator

# %%
# Data Input
import tensorflow as tf
import pandas as pd
import numpy as np
import shutil

CSV_COLUMNS = ['fare_amount', 'pickuplon', 'pickuplat', 'droppfflon', 'dropopplat', 'passengers', 'key']
FEATURES = CSV_COLUMNS[1:len(CSV_COLUMNS) - 1]
LABEL = CSV_COLUMNS[0]

df_train = pd.read_csv('./data/taxi-train.csv', header = None, names = CSV_COLUMNS)
df_valid = pd.read_csv('./data/taxi-valid.csv', header = None, names = CSV_COLUMNS)
df_test= pd.read_csv('./data/taxi-test.csv', header = None, names = CSV_COLUMNS)

# %%
# input function setup
def make_train_input_fn (df, num_epochs):
    return tf.compat.v1.estimator.inputs.pandas_input_fn(
        x = df,
        y = df[LABEL],
        num_epochs= num_epochs, #iteration
        shuffle = True, # read in random order
    )

def make_eval_input(df):
    return tf.compat.v1.estimator.inputs.pandas_input_fn(
        x = df,
        y = df[LABEL],
        shuffle = False
    )

def make_prediction_input(df):
    return tf.compat.v1.estimator.inputs.pandas_input_fn(
        x = df,
        y = None,
        shuffle = False
    )    

def make_feature_cols():
    input_columns = [tf.feature_column.numeric_column(k) for k in FEATURES] # ???
    return input_columns

# %%
# Linear Regressor Setup
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.INFO)

OUTDIR = 'taxi_trained'
shutil.rmtree(OUTDIR, ignore_errors = True) # start fresh each time

model = tf.estimator.LinearRegressor(
      feature_columns = make_feature_cols(), model_dir = OUTDIR)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': 'taxi_trained', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(input_fn = make_train_input_fn(df_train, num_epochs = 10))
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\feature_column\feature_column_v2.py:540: Layer.add_variable (from tensorflow.python.keras.engine.base_layer_v1) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\optimizer_v2\ftrl.py:144: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\training\monitored_session.py:906: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into taxi_trained\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 201.06929, step = 0
# INFO:tensorflow:global_step/sec: 506.154
# INFO:tensorflow:loss = 112.6944, step = 100 (0.201 sec)
# INFO:tensorflow:global_step/sec: 639.68
# INFO:tensorflow:loss = 67.17638, step = 200 (0.155 sec)
# INFO:tensorflow:global_step/sec: 575.038
# INFO:tensorflow:loss = 60.546303, step = 300 (0.173 sec)
# INFO:tensorflow:global_step/sec: 435.147
# INFO:tensorflow:loss = 42.882153, step = 400 (0.232 sec)
# INFO:tensorflow:global_step/sec: 627.586
# INFO:tensorflow:loss = 108.385635, step = 500 (0.158 sec)
# INFO:tensorflow:global_step/sec: 626.216
# INFO:tensorflow:loss = 65.26765, step = 600 (0.162 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 608...
# INFO:tensorflow:Saving checkpoints for 608 into taxi_trained\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 608...
# INFO:tensorflow:Loss for final step: 21.146093.

# %%
# Validation
def print_rmse(model, df_valid):
    metrics = model.evaluate(input_fn = make_eval_input(df_valid))
    print('RMSE on dataset = {}'.format(np.sqrt(metrics['average_loss'])))

print_rmse(model, df_valid)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-07-16T13:24:11Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from taxi_trained\model.ckpt-608
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.28268s
# INFO:tensorflow:Finished evaluation at 2020-07-16-13:24:11
# INFO:tensorflow:Saving dict for global step 608: average_loss = 135.6016, global_step = 608, label/mean = 11.666427, loss = 126.64605, prediction/mean = 6.489812
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 608: taxi_trained\model.ckpt-608
# RMSE on dataset = 11.64480972290039

# %%
# Predition on the test set
predictions = model.predict(input_fn=make_prediction_input(df_test))
for item in predictions:
    print(item)
# Out:
# oat32)}
# {'predictions': array([6.502252], dtype=float32)}
# {'predictions': array([6.462436], dtype=float32)}
# {'predictions': array([6.5389094], dtype=float32)}
# {'predictions': array([6.5009365], dtype=float32)}
# {'predictions': array([6.5394955], dtype=float32)}
# {'predictions': array([6.5013633], dtype=float32)}
# {'predictions': array([6.500202], dtype=float32)}
# {'predictions': array([6.462678], dtype=float32)}
# {'predictions': array([6.4624147], dtype=float32)}
# {'predictions': array([6.4626656], dtype=float32)}
# {'predictions': array([6.500127], dtype=float32)}
# {'predictions': array([6.462468], dtype=float32)}
# {'predictions': array([6.4628773], dtype=float32)}
# {'predictions': array([6.4627304], dtype=float32)}
# {'predictions': array([6.5012674], dtype=float32)}
# {'predictions': array([6.500874], dtype=float32)}
# {'predictions': array([6.4625726], dtype=float32)}
# {'predictions': array([6.5398893], dtype=float32)}
# {'predictions': array([6.5389667], dtype=float32)}
# {'predictions': array([6.461185], dtype=float32)}
# {'predictions': array([6.463684], dtype=float32)}
# {'predictions': array([6.462267], dtype=float32)}
# {'predictions': array([6.499774], dtype=float32)}
# {'predictions': array([6.463375], dtype=float32)}
# {'predictions': array([6.462224], dtype=float32)}
# {'predictions': array([6.502822], dtype=float32)}
# {'predictions': array([6.5007687], dtype=float32)}
# {'predictions': array([6.6157856], dtype=float32)}
# {'predictions': array([6.4627504], dtype=float32)}
# {'predictions': array([6.462641], dtype=float32)}
# {'predictions': array([6.4634037], dtype=float32)}
# {'predictions': array([6.5005083], dtype=float32)}
# {'predictions': array([6.462166], dtype=float32)}
# {'predictions': array([6.4622674], dtype=float32)}
# {'predictions': array([6.5014534], dtype=float32)}
# {'predictions': array([6.462783], dtype=float32)}
# {'predictions': array([6.461959], dtype=float32)}
# {'predictions': array([6.5009756], dtype=float32)}
# {'predictions': array([6.4628987], dtype=float32)}
# {'predictions': array([6.6547832], dtype=float32)}
# {'predictions': array([6.4610996], dtype=float32)}
# {'predictions': array([6.616266], dtype=float32)}
# {'predictions': array([6.4623003], dtype=float32)}
# {'predictions': array([6.5764728], dtype=float32)}
# {'predictions': array([6.4602613], dtype=float32)}
# {'predictions': array([6.4631257], dtype=float32)}
# {'predictions': array([6.500313], dtype=float32)}
# {'predictions': array([6.4632044], dtype=float32)}
# {'predictions': array([6.652895], dtype=float32)}
# {'predictions': array([6.4624047], dtype=float32)}
# {'predictions': array([6.462641], dtype=float32)}
# {'predictions': array([6.559898], dtype=float32)}
# {'predictions': array([6.4641066], dtype=float32)}
# {'predictions': array([6.4623814], dtype=float32)}
# {'predictions': array([6.46295], dtype=float32)}
# {'predictions': array([6.4630895], dtype=float32)}
# {'predictions': array([6.4989905], dtype=float32)}
# {'predictions': array([6.496819], dtype=float32)}
# {'predictions': array([6.4636755], dtype=float32)}
# {'predictions': array([6.463027], dtype=float32)}
# {'predictions': array([6.4607615], dtype=float32)}
# {'predictions': array([6.5017967], dtype=float32)}
# {'predictions': array([6.463887], dtype=float32)}
# {'predictions': array([6.462256], dtype=float32)}
# {'predictions': array([6.530509], dtype=float32)}
# {'predictions': array([6.4624515], dtype=float32)}
# {'predictions': array([6.454218], dtype=float32)}
# {'predictions': array([6.46299], dtype=float32)}
# {'predictions': array([6.4625688], dtype=float32)}
# {'predictions': array([6.500346], dtype=float32)}
# {'predictions': array([6.4640226], dtype=float32)}
# {'predictions': array([6.615281], dtype=float32)}
# {'predictions': array([6.462411], dtype=float32)}
# {'predictions': array([6.4619513], dtype=float32)}
# {'predictions': array([6.538358], dtype=float32)}
# {'predictions': array([6.46277], dtype=float32)}
# {'predictions': array([6.501289], dtype=float32)}
# {'predictions': array([6.463302], dtype=float32)}
# {'predictions': array([6.46002], dtype=float32)}
# {'predictions': array([6.462842], dtype=float32)}
# {'predictions': array([6.4634256], dtype=float32)}
# {'predictions': array([6.462303], dtype=float32)}
# {'predictions': array([6.6138177], dtype=float32)}
# {'predictions': array([6.5007925], dtype=float32)}
# {'predictions': array([6.4999337], dtype=float32)}
# {'predictions': array([6.4628997], dtype=float32)}
# {'predictions': array([6.46434], dtype=float32)}
# {'predictions': array([6.462444], dtype=float32)}
# {'predictions': array([6.4628544], dtype=float32)}
# {'predictions': array([6.4629974], dtype=float32)}
# {'predictions': array([6.463293], dtype=float32)}
# {'predictions': array([6.5406537], dtype=float32)}
# {'predictions': array([6.4623322], dtype=float32)}
# {'predictions': array([6.462476], dtype=float32)}
# {'predictions': array([6.4626017], dtype=float32)}
# {'predictions': array([6.540511], dtype=float32)}
# {'predictions': array([6.538386], dtype=float32)}
# {'predictions': array([6.463809], dtype=float32)}
# {'predictions': array([6.462962], dtype=float32)}
# {'predictions': array([6.464206], dtype=float32)}
# {'predictions': array([6.462425], dtype=float32)}
# {'predictions': array([6.4602885], dtype=float32)}
# {'predictions': array([6.5009623], dtype=float32)}
# {'predictions': array([6.46258], dtype=float32)}
# {'predictions': array([6.5011225], dtype=float32)}
# {'predictions': array([6.4975944], dtype=float32)}
# {'predictions': array([6.5763187], dtype=float32)}
# {'predictions': array([6.4566336], dtype=float32)}
# {'predictions': array([6.4986963], dtype=float32)}
# {'predictions': array([6.57488], dtype=float32)}
# {'predictions': array([6.462514], dtype=float32)}
# {'predictions': array([6.539592], dtype=float32)}
# {'predictions': array([6.462657], dtype=float32)}
# {'predictions': array([6.501301], dtype=float32)}
# {'predictions': array([6.461568], dtype=float32)}
# {'predictions': array([6.462861], dtype=float32)}
# {'predictions': array([6.500251], dtype=float32)}
# {'predictions': array([6.46315], dtype=float32)}
# {'predictions': array([6.4947715], dtype=float32)}
# {'predictions': array([6.5009775], dtype=float32)}
# {'predictions': array([6.4624863], dtype=float32)}
# {'predictions': array([6.500926], dtype=float32)}
# {'predictions': array([6.4635878], dtype=float32)}
# {'predictions': array([6.5014124], dtype=float32)}
# {'predictions': array([6.462616], dtype=float32)}
# {'predictions': array([6.4633055], dtype=float32)}
# {'predictions': array([6.501501], dtype=float32)}
# {'predictions': array([6.4616027], dtype=float32)}
# {'predictions': array([6.53983], dtype=float32)}
# {'predictions': array([6.4625807], dtype=float32)}
# {'predictions': array([6.4981804], dtype=float32)}
# {'predictions': array([6.6534133], dtype=float32)}
# {'predictions': array([6.539262], dtype=float32)}
# {'predictions': array([6.5394015], dtype=float32)}
# {'predictions': array([6.464463], dtype=float32)}
# {'predictions': array([6.4982586], dtype=float32)}
# {'predictions': array([6.462314], dtype=float32)}
# {'predictions': array([6.5006537], dtype=float32)}
# {'predictions': array([6.463722], dtype=float32)}
# {'predictions': array([6.53647], dtype=float32)}
# {'predictions': array([6.4625664], dtype=float32)}
# {'predictions': array([6.4621897], dtype=float32)}
# {'predictions': array([6.46317], dtype=float32)}
# {'predictions': array([6.6530647], dtype=float32)}
# {'predictions': array([6.5395613], dtype=float32)}
# {'predictions': array([6.5003653], dtype=float32)}
# {'predictions': array([6.46418], dtype=float32)}
# {'predictions': array([6.4626045], dtype=float32)}
# {'predictions': array([6.4634686], dtype=float32)}
# {'predictions': array([6.4624405], dtype=float32)}
# {'predictions': array([6.6142616], dtype=float32)}
# {'predictions': array([6.4568996], dtype=float32)}
# {'predictions': array([6.462344], dtype=float32)}
# {'predictions': array([6.4627247], dtype=float32)}
# {'predictions': array([6.462785], dtype=float32)}
# {'predictions': array([6.6153336], dtype=float32)}
# {'predictions': array([6.53813], dtype=float32)}
# {'predictions': array([6.462883], dtype=float32)}
# {'predictions': array([6.653534], dtype=float32)}
# {'predictions': array([6.463963], dtype=float32)}
# {'predictions': array([6.4621754], dtype=float32)}
# {'predictions': array([6.4633737], dtype=float32)}
# {'predictions': array([6.462871], dtype=float32)}
# {'predictions': array([6.4626303], dtype=float32)}
# {'predictions': array([6.4630632], dtype=float32)}
# {'predictions': array([6.4619474], dtype=float32)}
# {'predictions': array([6.4641867], dtype=float32)}
# {'predictions': array([6.462411], dtype=float32)}
# {'predictions': array([6.462183], dtype=float32)}
# {'predictions': array([6.462377], dtype=float32)}
# {'predictions': array([6.4628344], dtype=float32)}
# {'predictions': array([6.4626927], dtype=float32)}
# {'predictions': array([6.4609275], dtype=float32)}
# {'predictions': array([6.5001864], dtype=float32)}
# {'predictions': array([6.4601684], dtype=float32)}
# {'predictions': array([6.4633355], dtype=float32)}
# {'predictions': array([6.4626045], dtype=float32)}
# {'predictions': array([6.4627004], dtype=float32)}
# {'predictions': array([6.4602413], dtype=float32)}
# {'predictions': array([6.4633627], dtype=float32)}
# {'predictions': array([6.4641747], dtype=float32)}
# {'predictions': array([6.464361], dtype=float32)}
# {'predictions': array([6.540733], dtype=float32)}
# {'predictions': array([6.4624624], dtype=float32)}
# {'predictions': array([6.462694], dtype=float32)}
# {'predictions': array([6.539237], dtype=float32)}
# {'predictions': array([6.462083], dtype=float32)}
# {'predictions': array([6.4638596], dtype=float32)}
# {'predictions': array([6.6538253], dtype=float32)}
# {'predictions': array([6.6163607], dtype=float32)}
# {'predictions': array([6.462739], dtype=float32)}
# {'predictions': array([6.4927335], dtype=float32)}
# {'predictions': array([6.4637985], dtype=float32)}
# {'predictions': array([6.615159], dtype=float32)}
# {'predictions': array([6.463505], dtype=float32)}
# {'predictions': array([6.4636936], dtype=float32)}
# {'predictions': array([6.6151724], dtype=float32)}
# {'predictions': array([6.5007467], dtype=float32)}
# {'predictions': array([6.4627028], dtype=float32)}
# {'predictions': array([6.463443], dtype=float32)}
# {'predictions': array([6.5752296], dtype=float32)}
# {'predictions': array([6.500618], dtype=float32)}
# {'predictions': array([6.614298], dtype=float32)}
# {'predictions': array([6.5016594], dtype=float32)}
# {'predictions': array([6.576559], dtype=float32)}
# {'predictions': array([6.500705], dtype=float32)}
# {'predictions': array([6.463511], dtype=float32)}
# {'predictions': array([6.4553585], dtype=float32)}
# {'predictions': array([6.4627657], dtype=float32)}
# {'predictions': array([6.4624634], dtype=float32)}
# {'predictions': array([6.4622326], dtype=float32)}
# {'predictions': array([6.4624557], dtype=float32)}
# {'predictions': array([6.5025444], dtype=float32)}
# {'predictions': array([6.4626994], dtype=float32)}
# {'predictions': array([6.463674], dtype=float32)}
# {'predictions': array([6.616543], dtype=float32)}
# {'predictions': array([6.539651], dtype=float32)}
# {'predictions': array([6.4630284], dtype=float32)}
# {'predictions': array([6.4632015], dtype=float32)}
# {'predictions': array([6.45941], dtype=float32)}
# {'predictions': array([6.4617248], dtype=float32)}
# {'predictions': array([6.4643035], dtype=float32)}
# {'predictions': array([6.459927], dtype=float32)}
# {'predictions': array([6.653639], dtype=float32)}
# {'predictions': array([6.4628468], dtype=float32)}
# {'predictions': array([6.460923], dtype=float32)}
# {'predictions': array([6.4629574], dtype=float32)}
# {'predictions': array([6.6162944], dtype=float32)}
# {'predictions': array([6.501649], dtype=float32)}
# {'predictions': array([6.462865], dtype=float32)}
# {'predictions': array([6.463352], dtype=float32)}
# {'predictions': array([6.500286], dtype=float32)}
# {'predictions': array([6.4613514], dtype=float32)}
# {'predictions': array([6.462416], dtype=float32)}
# {'predictions': array([6.6163483], dtype=float32)}
# {'predictions': array([6.5390043], dtype=float32)}
# {'predictions': array([6.462693], dtype=float32)}
# {'predictions': array([6.463068], dtype=float32)}
# {'predictions': array([6.4628706], dtype=float32)}
# {'predictions': array([6.4622207], dtype=float32)}
# {'predictions': array([6.462234], dtype=float32)}
# {'predictions': array([6.5008707], dtype=float32)}
# {'predictions': array([6.461899], dtype=float32)}
# {'predictions': array([6.6145267], dtype=float32)}
# {'predictions': array([6.4627047], dtype=float32)}
# {'predictions': array([6.462831], dtype=float32)}
# {'predictions': array([6.4630933], dtype=float32)}
# {'predictions': array([6.462509], dtype=float32)}
# {'predictions': array([6.5393314], dtype=float32)}
# {'predictions': array([6.4633865], dtype=float32)}
# {'predictions': array([6.4623203], dtype=float32)}
# {'predictions': array([6.464013], dtype=float32)}
# {'predictions': array([6.500638], dtype=float32)}
# {'predictions': array([6.4634714], dtype=float32)}
# {'predictions': array([6.4984035], dtype=float32)}
# {'predictions': array([6.463678], dtype=float32)}
# {'predictions': array([6.463505], dtype=float32)}
# {'predictions': array([6.49223], dtype=float32)}
# {'predictions': array([6.4499073], dtype=float32)}
# {'predictions': array([6.463067], dtype=float32)}
# {'predictions': array([6.464408], dtype=float32)}
# {'predictions': array([6.4615436], dtype=float32)}
# {'predictions': array([6.5008736], dtype=float32)}
# {'predictions': array([6.4626513], dtype=float32)}
# {'predictions': array([6.460191], dtype=float32)}
# {'predictions': array([6.462263], dtype=float32)}
# {'predictions': array([6.611494], dtype=float32)}
# {'predictions': array([6.5392103], dtype=float32)}
# {'predictions': array([6.4623566], dtype=float32)}
# {'predictions': array([6.4632125], dtype=float32)}
# {'predictions': array([6.538269], dtype=float32)}
# {'predictions': array([6.4627085], dtype=float32)}
# {'predictions': array([6.615452], dtype=float32)}
# {'predictions': array([6.4626603], dtype=float32)}
# {'predictions': array([6.462466], dtype=float32)}
# {'predictions': array([6.501279], dtype=float32)}
# {'predictions': array([6.6533403], dtype=float32)}
# {'predictions': array([6.4616423], dtype=float32)}
# {'predictions': array([6.461165], dtype=float32)}
# {'predictions': array([6.497215], dtype=float32)}
# {'predictions': array([6.4616566], dtype=float32)}
# {'predictions': array([6.462421], dtype=float32)}
# {'predictions': array([6.500867], dtype=float32)}
# {'predictions': array([6.6149187], dtype=float32)}
# {'predictions': array([6.536372], dtype=float32)}
# {'predictions': array([6.4624796], dtype=float32)}
# {'predictions': array([6.4622684], dtype=float32)}
# {'predictions': array([6.5008473], dtype=float32)}
# {'predictions': array([6.460055], dtype=float32)}
# {'predictions': array([6.463827], dtype=float32)}
# {'predictions': array([6.6159134], dtype=float32)}
# {'predictions': array([6.46241], dtype=float32)}
# {'predictions': array([6.614611], dtype=float32)}
# {'predictions': array([6.4641547], dtype=float32)}
# {'predictions': array([6.6147714], dtype=float32)}
# {'predictions': array([6.4627504], dtype=float32)}
# {'predictions': array([6.4629564], dtype=float32)}
# {'predictions': array([6.5024877], dtype=float32)}
# {'predictions': array([6.445937], dtype=float32)}
# {'predictions': array([6.4626117], dtype=float32)}
# {'predictions': array([6.4612837], dtype=float32)}
# {'predictions': array([6.4645224], dtype=float32)}
# {'predictions': array([6.462502], dtype=float32)}
# {'predictions': array([6.4633646], dtype=float32)}
# {'predictions': array([6.4635353], dtype=float32)}
# {'predictions': array([6.4622574], dtype=float32)}
# {'predictions': array([6.6152453], dtype=float32)}
# {'predictions': array([6.4619207], dtype=float32)}
# {'predictions': array([6.575473], dtype=float32)}
# {'predictions': array([6.4642067], dtype=float32)}
# {'predictions': array([6.462909], dtype=float32)}
# {'predictions': array([6.462243], dtype=float32)}
# {'predictions': array([6.462115], dtype=float32)}
# {'predictions': array([6.653599], dtype=float32)}
# {'predictions': array([6.4513507], dtype=float32)}
# {'predictions': array([6.4637556], dtype=float32)}
# {'predictions': array([6.615612], dtype=float32)}
# {'predictions': array([6.4628377], dtype=float32)}
# {'predictions': array([6.4630613], dtype=float32)}
# {'predictions': array([6.454256], dtype=float32)}
# {'predictions': array([6.46285], dtype=float32)}
# {'predictions': array([6.462725], dtype=float32)}
# {'predictions': array([6.5011144], dtype=float32)}
# {'predictions': array([6.462591], dtype=float32)}
# {'predictions': array([6.4624176], dtype=float32)}
# {'predictions': array([6.46292], dtype=float32)}
# {'predictions': array([6.4635124], dtype=float32)}
# {'predictions': array([6.5001035], dtype=float32)}
# {'predictions': array([6.5393834], dtype=float32)}
# {'predictions': array([6.462491], dtype=float32)}
# {'predictions': array([6.462612], dtype=float32)}
# {'predictions': array([6.4503508], dtype=float32)}
# {'predictions': array([6.4612403], dtype=float32)}
# {'predictions': array([6.4629407], dtype=float32)}
# {'predictions': array([6.4620028], dtype=float32)}
# {'predictions': array([6.462428], dtype=float32)}
# {'predictions': array([6.500514], dtype=float32)}
# {'predictions': array([6.5006847], dtype=float32)}
# {'predictions': array([6.4623084], dtype=float32)}
# {'predictions': array([6.615674], dtype=float32)}
# {'predictions': array([6.6162705], dtype=float32)}
# {'predictions': array([6.5395894], dtype=float32)}
# {'predictions': array([6.4591665], dtype=float32)}
# {'predictions': array([6.463235], dtype=float32)}
# {'predictions': array([6.6162343], dtype=float32)}
# {'predictions': array([6.5010786], dtype=float32)}
# {'predictions': array([6.4633636], dtype=float32)}
# {'predictions': array([6.4631233], dtype=float32)}
# {'predictions': array([6.540383], dtype=float32)}
# {'predictions': array([6.4633126], dtype=float32)}
# {'predictions': array([6.4628386], dtype=float32)}
# {'predictions': array([6.4669003], dtype=float32)}
# {'predictions': array([6.4625454], dtype=float32)}
# {'predictions': array([6.4624066], dtype=float32)}
# {'predictions': array([6.612786], dtype=float32)}
# {'predictions': array([6.4582095], dtype=float32)}
# {'predictions': array([6.4628], dtype=float32)}
# {'predictions': array([6.6152396], dtype=float32)}
# {'predictions': array([6.462614], dtype=float32)}
# {'predictions': array([6.463051], dtype=float32)}
# {'predictions': array([6.4988604], dtype=float32)}
# {'predictions': array([6.4590454], dtype=float32)}
# {'predictions': array([6.462928], dtype=float32)}
# {'predictions': array([6.500353], dtype=float32)}
# {'predictions': array([6.4630527], dtype=float32)}
# {'predictions': array([6.613158], dtype=float32)}
# {'predictions': array([6.4634895], dtype=float32)}
# {'predictions': array([6.538164], dtype=float32)}
# {'predictions': array([6.6155267], dtype=float32)}
# {'predictions': array([6.616668], dtype=float32)}
# {'predictions': array([6.45439], dtype=float32)}
# {'predictions': array([6.461422], dtype=float32)}
# {'predictions': array([6.4630756], dtype=float32)}
# {'predictions': array([6.463744], dtype=float32)}
# {'predictions': array([6.61493], dtype=float32)}
# {'predictions': array([6.463197], dtype=float32)}
# {'predictions': array([6.4608364], dtype=float32)}
# {'predictions': array([6.463203], dtype=float32)}
# {'predictions': array([6.4633427], dtype=float32)}
# {'predictions': array([6.5777736], dtype=float32)}
# {'predictions': array([6.4631386], dtype=float32)}
# {'predictions': array([6.501789], dtype=float32)}
# {'predictions': array([6.499093], dtype=float32)}
# {'predictions': array([6.462632], dtype=float32)}
# {'predictions': array([6.463396], dtype=float32)}
# {'predictions': array([6.463025], dtype=float32)}
# {'predictions': array([6.5009484], dtype=float32)}
# {'predictions': array([6.4618826], dtype=float32)}
# {'predictions': array([6.4634805], dtype=float32)}
# {'predictions': array([6.6533203], dtype=float32)}
# {'predictions': array([6.462761], dtype=float32)}
# {'predictions': array([6.4621296], dtype=float32)}
# {'predictions': array([6.462059], dtype=float32)}
# {'predictions': array([6.653536], dtype=float32)}
# {'predictions': array([6.462793], dtype=float32)}
# {'predictions': array([6.495909], dtype=float32)}

# %% [markdown]
# # Deep Neural Network

# %%
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.INFO)
shutil.rmtree(OUTDIR, ignore_errors = True) # start fresh each time
model = tf.estimator.DNNRegressor(hidden_units = [32, 8, 2],
      feature_columns = make_feature_cols(), model_dir = OUTDIR)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': 'taxi_trained', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(input_fn = make_train_input_fn(df_train, num_epochs = 100));
print_rmse(model, df_valid)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into taxi_trained\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 366.02936, step = 0
# INFO:tensorflow:global_step/sec: 456.575
# INFO:tensorflow:loss = 231.29727, step = 100 (0.221 sec)
# INFO:tensorflow:global_step/sec: 577.839
# INFO:tensorflow:loss = 195.90994, step = 200 (0.173 sec)
# INFO:tensorflow:global_step/sec: 446.293
# INFO:tensorflow:loss = 287.46594, step = 300 (0.224 sec)
# INFO:tensorflow:global_step/sec: 430.844
# INFO:tensorflow:loss = 225.1143, step = 400 (0.231 sec)
# INFO:tensorflow:global_step/sec: 458.637
# INFO:tensorflow:loss = 208.86024, step = 500 (0.220 sec)
# INFO:tensorflow:global_step/sec: 561.597
# INFO:tensorflow:loss = 170.16574, step = 600 (0.178 sec)
# INFO:tensorflow:global_step/sec: 582.309
# INFO:tensorflow:loss = 166.81088, step = 700 (0.170 sec)
# INFO:tensorflow:global_step/sec: 630.521
# INFO:tensorflow:loss = 219.78609, step = 800 (0.160 sec)
# INFO:tensorflow:global_step/sec: 640.373
# INFO:tensorflow:loss = 173.33206, step = 900 (0.155 sec)
# INFO:tensorflow:global_step/sec: 609.313
# INFO:tensorflow:loss = 155.04448, step = 1000 (0.165 sec)
# INFO:tensorflow:global_step/sec: 616.805
# INFO:tensorflow:loss = 149.8448, step = 1100 (0.161 sec)
# INFO:tensorflow:global_step/sec:
 (0.157 sec)
# INFO:tensorflow:global_step/sec: 661.938
# INFO:tensorflow:loss = 224.78552, step = 4300 (0.151 sec)
# INFO:tensorflow:global_step/sec: 618.695
# INFO:tensorflow:loss = 214.06354, step = 4400 (0.162 sec)
# INFO:tensorflow:global_step/sec: 607.052
# INFO:tensorflow:loss = 183.17104, step = 4500 (0.165 sec)
# INFO:tensorflow:global_step/sec: 532.499
# INFO:tensorflow:loss = 138.81415, step = 4600 (0.188 sec)
# INFO:tensorflow:global_step/sec: 492.451
# INFO:tensorflow:loss = 199.49893, step = 4700 (0.204 sec)
# INFO:tensorflow:global_step/sec: 493.198
# INFO:tensorflow:loss = 127.936066, step = 4800 (0.203 sec)
# INFO:tensorflow:global_step/sec: 531.312
# INFO:tensorflow:loss = 219.8586, step = 4900 (0.190 sec)
# INFO:tensorflow:global_step/sec: 458.421
# INFO:tensorflow:loss = 213.10849, step = 5000 (0.217 sec)
# INFO:tensorflow:global_step/sec: 504.976
# INFO:tensorflow:loss = 138.23938, step = 5100 (0.196 sec)
# INFO:tensorflow:global_step/sec: 596.611
# INFO:tensorflow:loss = 215.79655, step = 5200 (0.168 sec)
# INFO:tensorflow:global_step/sec: 525.405
# INFO:tensorflow:loss = 237.55765, step = 5300 (0.213 sec)
# INFO:tensorflow:global_step/sec: 408.875
# INFO:tensorflow:loss = 201.732, step = 5400 (0.222 sec)
# INFO:tensorflow:global_step/sec: 483.076
# INFO:tensorflow:loss = 278.98492, step = 5500 (0.206 sec)
# INFO:tensorflow:global_step/sec: 557.675
# INFO:tensorflow:loss = 231.33131, step = 5600 (0.179 sec)
# INFO:tensorflow:global_step/sec: 546.695
# INFO:tensorflow:loss = 248.40779, step = 5700 (0.186 sec)
# INFO:tensorflow:global_step/sec: 538.12
# INFO:tensorflow:loss = 183.27039, step = 5800 (0.184 sec)
# INFO:tensorflow:global_step/sec: 578.587
# INFO:tensorflow:loss = 126.240364, step = 5900 (0.174 sec)
# INFO:tensorflow:global_step/sec: 325.689
# INFO:tensorflow:loss = 199.44653, step = 6000 (0.309 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 6071...
# INFO:tensorflow:Saving checkpoints for 6071 into taxi_trained\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 6071...
# INFO:tensorflow:Loss for final step: 265.70453.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-07-16T13:31:58Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from taxi_trained\model.ckpt-6071
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.29942s
# INFO:tensorflow:Finished evaluation at 2020-07-16-13:31:58
# INFO:tensorflow:Saving dict for global step 6071: average_loss = 241.4641, global_step = 6071, label/mean = 11.666427, loss = 225.1479, prediction/mean = 0.14755489
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6071: taxi_trained\model.ckpt-6071
# RMSE on dataset = 15.539114952087402

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import shutil

# Data Generation
COLUMNS = ['base', 'height', 'volumn']
FEATURES = ['base', 'height']
LABEL = 'volumn'


def cylinder_df_generator(size, df : pd.DataFrame(columns = COLUMNS)):
    df['base'] = np.random.random(size) * 1.5 + 0.5
    df['height'] = np.random.random(size) * 1.5 + 0.5
    df['volumn'] = df['base'] * df['base'] * np.pi * df['height']
    return df

cylinder_train = pd.DataFrame(columns = COLUMNS)
cylinder_train = cylinder_df_generator(2000, cylinder_train)

cylinder_valid = pd.DataFrame(columns = COLUMNS)
cylinder_valid = cylinder_df_generator(500, cylinder_valid)

cylinder_test = pd.DataFrame(columns = COLUMNS)
cylinder_test = cylinder_df_generator(500, cylinder_test)

'''
CSV_COLUMNS = ['fare_amount', 'pickuplon', 'pickuplat', 'droppfflon', 'dropopplat', 'passengers', 'key']
FEATURES = CSV_COLUMNS[1:len(CSV_COLUMNS) - 1]
LABEL = CSV_COLUMNS[0]

df_train = pd.read_csv('./data/taxi-train.csv', header = None, names = CSV_COLUMNS)
df_valid = pd.read_csv('./data/taxi-valid.csv', header = None, names = CSV_COLUMNS)
df_test= pd.read_csv('./data/taxi-test.csv', header = None, names = CSV_COLUMNS)
'''
# Out:
# "\nCSV_COLUMNS = ['fare_amount', 'pickuplon', 'pickuplat', 'droppfflon', 'dropopplat', 'passengers', 'key']\nFEATURES = CSV_COLUMNS[1:len(CSV_COLUMNS) - 1]\nLABEL = CSV_COLUMNS[0]\n\ndf_train = pd.read_csv('./data/taxi-train.csv', header = None, names = CSV_COLUMNS)\ndf_valid = pd.read_csv('./data/taxi-valid.csv', header = None, names = CSV_COLUMNS)\ndf_test= pd.read_csv('./data/taxi-test.csv', header = None, names = CSV_COLUMNS)\n"

# %%
def make_train_input_fn(df, num_epochs):
    return tf.compat.v1.estimator.inputs.pandas_input_fn(
        x = df,
        y = df[LABEL],
        num_epochs = num_epochs,
        shuffle = True
    )

def make_eval_input_fn(df):
    return tf.compat.v1.estimator.inputs.pandas_input_fn(
        x = df,
        y = df[LABEL],
        shuffle = False
    )

def make_prediction_input_fn(df):
    return tf.compat.v1.estimator.inputs.pandas_input_fn(
        x = df,
        y = None,
        shuffle = False
    )

def make_feature_cols():
    input_columns = [tf.feature_column.numeric_column(f) for f in FEATURES]
    return input_columns

# %%
OUTDIR = 'cylinder'
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.INFO)
shutil.rmtree(OUTDIR, ignore_errors = True) # start fresh each time

model = tf.estimator.DNNRegressor(hidden_units = [32, 8, 2],
      feature_columns = make_feature_cols(), model_dir = OUTDIR)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': 'cylinder', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(input_fn = make_train_input_fn(cylinder_train, num_epochs = 1000))
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cylinder\model.ckpt-1563
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py:1077: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1563...
# INFO:tensorflow:Saving checkpoints for 1563 into cylinder\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1563...
# INFO:tensorflow:loss = 34.205193, step = 1563
# INFO:tensorflow:global_step/sec: 739.203
# INFO:tensorflow:loss = 34.968594, step = 1663 (0.138 sec)
# INFO:tensorflow:global_step/sec: 753.656
# INFO:tensorflow:loss = 36.16023, step = 1763 (0.132 sec)
# INFO:tensorflow:global_step/sec: 841.505
# INFO:tensorflow:loss = 35.130898, step = 1863 (0.119 sec)
# INFO:tensorflow:global_step/sec: 868.762
# INFO:tensorflow:loss = 32.27979, step = 1963 (0.117 sec)
# INFO:tensorflow:global_step/sec: 947.439
# INFO:tensorflow:loss = 39.78936, step = 2063 (0.103 sec)
# INFO:tensorflow:global_step/sec: 921.252
# INFO:tensorflow:loss = 31.366962, step = 2163 (0.109 sec)
# INFO:tensorflow:global_step/sec: 857.876
# INFO:tensorflow:loss = 34.88585, step = 2263 (0.117 sec)
# INFO:tensorflow:global_step/sec: 843.281
# INFO:tensorflow:loss = 26.37861, step = 2363 (0.118 sec)
# INFO:tensorflow:global_step/sec: 715.49
# INFO:tensorflow:loss = 36.414925, step = 2463 (0.140 sec)
# INFO:tensorflow:global_step/sec: 860.458
# INFO:tensorflow:loss = 24.824589, step = 2563 (0.117 sec)
# INFO:tensorflow:global_step/sec: 849.065
# INFO:tensorflow:loss = 29.002682, step = 2663 (0.118 sec)
# INFO:tensorflow:global_step/sec: 842.02
# INFO:tensorflow:loss = 29.206617, step = 2763 (0.117 sec)
# INFO:tensorflow:global_step/sec: 891.481
# INFO:tensorflow:loss = 13.997212, step = 2863 (0.113 sec)
# INFO:tensorflow:global_step/sec: 893.441
# INFO:tensorflow:loss = 25.698437, step = 2963 (0.112 sec)
# INFO:tensorflow:global_step/sec: 908.098
# INFO:tensorflow:loss = 32.678497, step = 3063 (0.110 sec)
# INFO:tensorflow:global_step/sec: 922.115
# INFO:tensorflow:loss = 24.79269, step = 3163 (0.110 sec)
# INFO:tensorflow:global_step/sec: 881.473
# INFO:tensorflow:loss = 23.974836, step = 3263 (0.112 sec)
# INFO:tensorflow:global_step/sec: 925.582
# INFO:tensorflow:loss = 25.531878, step = 3363 (0.109 sec)
# INFO:tensorflow:global_step/sec: 836.704
# INFO:tensorflow:global_step/sec: 890.819
# INFO:tensorflow:loss = 12.393602, step = 16863 (0.113 sec)
# INFO:tensorflow:global_step/sec: 823
# INFO:tensorflow:loss = 13.204103, step = 16963 (0.120 sec)
# INFO:tensorflow:global_step/sec: 961.815
# INFO:tensorflow:loss = 19.453133, step = 17063 (0.105 sec)
# INFO:tensorflow:global_step/sec: 814.645
# INFO:tensorflow:loss = 12.235953, step = 17163 (0.122 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 17188...
# INFO:tensorflow:Saving checkpoints for 17188 into cylinder\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 17188...
# INFO:tensorflow:Loss for final step: 13.980223.

# %%
# Validation
def print_rmse(model, df_valid):
    metrics = model.evaluate(input_fn = make_eval_input(df_valid))
    print('RMSE on dataset = {}'.format(np.sqrt(metrics['average_loss'])))

print_rmse(model, cylinder_valid)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-07-16T18:05:05Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cylinder\model.ckpt-17188
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.24120s
# INFO:tensorflow:Finished evaluation at 2020-07-16-18:05:05
# INFO:tensorflow:Saving dict for global step 17188: average_loss = 14.136398, global_step = 17188, label/mean = 6.9715047, loss = 14.140915, prediction/mean = 7.4352384
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 17188: cylinder\model.ckpt-17188
# RMSE on dataset = 3.759840250015259

# %%
# Test
predictions = model.predict(input_fn=make_prediction_input_fn(cylinder_test))
for item in predictions:
    print(item)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cylinder\model.ckpt-17188
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# {'predictions': array([5.404317], dtype=float32)}
# {'predictions': array([7.301649], dtype=float32)}
# {'predictions': array([8.295534], dtype=float32)}
# {'predictions': array([5.9205694], dtype=float32)}
# {'predictions': array([7.472376], dtype=float32)}
# {'predictions': array([7.7321496], dtype=float32)}
# {'predictions': array([5.1033897], dtype=float32)}
# {'predictions': array([6.3310585], dtype=float32)}
# {'predictions': array([6.903353], dtype=float32)}
# {'predictions': array([9.707816], dtype=float32)}
# {'predictions': array([6.7099223], dtype=float32)}
# {'predictions': array([6.808327], dtype=float32)}
# {'predictions': array([6.652413], dtype=float32)}
# {'predictions': array([5.30793], dtype=float32)}
# {'predictions': array([7.23942], dtype=float32)}
# {'predictions': array([7.1808705], dtype=float32)}
# {'predictions': array([8.616548], dtype=float32)}
# {'predictions': array([6.098531], dtype=float32)}
# {'predictions': array([8.059369], dtype=float32)}
# {'predictions': array([5.0553336], dtype=float32)}
# {'predictions': array([7.960014], dtype=float32)}
# {'predictions': array([7.7745767], dtype=float32)}
# {'predictions': array([10.444332], dtype=float32)}
# {'predictions': array([5.7796187], dtype=float32)}
# {'predictions': array([4.4451704], dtype=float32)}
# {'predictions': array([6.3269663], dtype=float32)}
# {'predictions': array([5.6610994], dtype=float32)}
# {'predictions': array([4.4191256], dtype=float32)}
# {'predictions': array([6.1899114], dtype=float32)}
# {'predictions': array([7.261074], dtype=float32)}
# {'predictions': array([10.638719], dtype=float32)}
# {'predictions': array([6.0992165], dtype=float32)}
# {'predictions': array([7.9145327], dtype=float32)}
# {'predictions': array([4.2177477], dtype=float32)}
# {'predictions': array([7.7426014], dtype=float32)}
# {'predictions': array([7.7206516], dtype=float32)}
# {'predictions': array([5.5922184], dtype=float32)}
# {'predictions': array([8.913866], dtype=float32)}
# {'predictions': array([7.173131], dtype=float32)}
# {'predictions': array([6.8924513], dtype=float32)}
# {'predictions': array([7.387925], dtype=float32)}
# {'predictions': array([10.628722], dtype=float32)}
# {'predictions': array([5.567238], dtype=float32)}
# {'predictions': array([6.59369], dtype=float32)}
# {'predictions': array([8.654537], dtype=float32)}
# {'predictions': array([9.853057], dtype=float32)}
# {'predictions': array([5.1979904], dtype=float32)}
# {'predictions': array([5.245431], dtype=float32)}
# {'predictions': array([7.213623], dtype=float32)}
# {'predictions': array([7.6093006], dtype=float32)}
# {'predictions': array([6.9340744], dtype=float32)}
# {'predictions': array([7.0839806], dtype=float32)}
# {'predictions': array([8.906153], dtype=float32)}
# {'predictions': array([5.670827], dtype=float32)}
# {'predictions': array([9.221494], dtype=float32)}
# {'predictions': array([6.001281], dtype=float32)}
# {'predictions': array([7.4552007], dtype=float32)}
# {'predictions': array([5.937424], dtype=float32)}
# {'predictions': array([10.152817], dtype=float32)}
# {'predictions': array([6.4056573], dtype=float32)}
# {'predictions': array([6.550197], dtype=float32)}
# {'predictions': array([7.1101665], dtype=float32)}
# {'predictions': array([4.7174067], dtype=float32)}
# {'predictions': array([8.360331], dtype=float32)}
# {'predictions': array([7.459425], dtype=float32)}
# {'predictions': array([4.3082223], dtype=float32)}
# {'predictions': array([8.150205], dtype=float32)}
# {'predictions': array([6.077878], dtype=float32)}
# {'predictions': array([5.7089825], dtype=float32)}
# {'predictions': array([7.687647], dtype=float32)}
# {'predictions': array([7.4394712], dtype=float32)}
# {'predictions': array([6.173728], dtype=float32)}
# {'predictions': array([7.7638636], dtype=float32)}
# {'predictions': array([9.579108], dtype=float32)}
# {'predictions': array([4.4145613], dtype=float32)}
# {'predictions': array([10.939468], dtype=float32)}
# {'predictions': array([7.9932785], dtype=float32)}
# {'predictions': array([6.983259], dtype=float32)}
# {'predictions': array([8.97487], dtype=float32)}
# {'predictions': array([6.641476], dtype=float32)}
# {'predictions': array([6.6065435], dtype=float32)}
# {'predictions': array([7.741581], dtype=float32)}
# {'predictions': array([7.363162], dtype=float32)}
# {'predictions': array([10.466845], dtype=float32)}
# {'predictions': array([9.131904], dtype=float32)}
# {'predictions': array([5.776035], dtype=float32)}
# {'predictions': array([6.754258], dtype=float32)}
# {'predictions': array([6.6507106], dtype=float32)}
# {'predictions': array([7.05396], dtype=float32)}
# {'predictions': array([8.355897], dtype=float32)}
# {'predictions': array([9.546345], dtype=float32)}
# {'predictions': array([5.476037], dtype=float32)}
# {'predictions': array([4.170083], dtype=float32)}
# {'predictions': array([7.8011975], dtype=float32)}
# {'predictions': array([7.7764606], dtype=float32)}
# {'predictions': array([4.482363], dtype=float32)}
# {'predictions': array([8.916538], dtype=float32)}
# {'predictions': array([5.241199], dtype=float32)}
# {'predictions': array([4.861596], dtype=float32)}
# {'predictions': array([8.442705], dtype=float32)}
# {'predictions': array([5.513647], dtype=float32)}
# {'predictions': array([10.645883], dtype=float32)}
# {'predictions': array([5.974119], dtype=float32)}
# {'predictions': array([8.8262615], dtype=float32)}
# {'predictions': array([6.0744414], dtype=float32)}
# {'predictions': array([7.8207645], dtype=float32)}
# {'predictions': array([7.841852], dtype=float32)}
# {'predictions': array([8.27763], dtype=float32)}
# {'predictions': array([7.4062967], dtype=float32)}
# {'predictions': array([9.023323], dtype=float32)}
# {'predictions': array([6.979778], dtype=float32)}
# {'predictions': array([6.0474224], dtype=float32)}
# {'predictions': array([7.1257467], dtype=float32)}
# {'predictions': array([6.647472], dtype=float32)}
# {'predictions': array([6.297535], dtype=float32)}
# {'predictions': array([7.7912607], dtype=float32)}
# {'predictions': array([6.053355], dtype=float32)}
# {'predictions': array([9.631177], dtype=float32)}
# {'predictions': array([9.874666], dtype=float32)}
# {'predictions': array([8.090824], dtype=float32)}
# {'predictions': array([7.473993], dtype=float32)}
# {'predictions': array([5.456221], dtype=float32)}
# {'predictions': array([8.046497], dtype=float32)}
# {'predictions': array([7.469776], dtype=float32)}
# {'predictions': array([4.63282], dtype=float32)}
# {'predictions': array([8.749329], dtype=float32)}
# {'predictions': array([7.5944953], dtype=float32)}
# {'predictions': array([6.33451], dtype=float32)}
# {'predictions': array([6.2567663], dtype=float32)}
# {'predictions': array([9.923502], dtype=float32)}
# {'predictions': array([6.1788216], dtype=float32)}
# {'predictions': array([7.9011087], dtype=float32)}
# {'predictions': array([8.125287], dtype=float32)}
# {'predictions': array([9.333481], dtype=float32)}
# {'predictions': array([5.9133844], dtype=float32)}
# {'predictions': array([5.8315477], dtype=float32)}
# {'predictions': array([8.092129], dtype=float32)}
# {'predictions': array([8.90289], dtype=float32)}
# {'predictions': array([7.3378096], dtype=float32)}
# {'predictions': array([6.592955], dtype=float32)}
# {'predictions': array([8.702208], dtype=float32)}
# {'predictions': array([5.9170046], dtype=float32)}
# {'predictions': array([9.837699], dtype=float32)}
# {'predictions': array([9.956808], dtype=float32)}
# {'predictions': array([6.9964185], dtype=float32)}
# {'predictions': array([7.6951666], dtype=float32)}
# {'predictions': array([4.3275027], dtype=float32)}
# {'predictions': array([9.292599], dtype=float32)}
# {'predictions': array([8.932789], dtype=float32)}
# {'predictions': array([6.28441], dtype=float32)}
# {'predictions': array([5.288787], dtype=float32)}
# {'predictions': array([7.9224186], dtype=float32)}
# {'predictions': array([8.498821], dtype=float32)}
# {'predictions': array([4.665576], dtype=float32)}
# {'predictions': array([10.512619], dtype=float32)}
# {'predictions': array([6.590381], dtype=float32)}
# {'predictions': array([6.7114677], dtype=float32)}
# {'predictions': array([4.7910967], dtype=float32)}
# {'predictions': array([5.601963], dtype=float32)}
# {'predictions': array([8.036686], dtype=float32)}
# {'predictions': array([5.724741], dtype=float32)}
# {'predictions': array([6.9781694], dtype=float32)}
# {'predictions': array([6.334939], dtype=float32)}
# {'predictions': array([9.910178], dtype=float32)}
# {'predictions': array([7.1259317], dtype=float32)}
# {'predictions': array([6.390974], dtype=float32)}
# {'predictions': array([7.520749], dtype=float32)}
# {'predictions': array([7.5808334], dtype=float32)}
# {'predictions': array([5.892798], dtype=float32)}
# {'predictions': array([8.965261], dtype=float32)}
# {'predictions': array([7.9330826], dtype=float32)}
# {'predictions': array([5.8863277], dtype=float32)}
# {'predictions': array([6.679798], dtype=float32)}
# {'predictions': array([6.8445606], dtype=float32)}
# {'predictions': array([9.263437], dtype=float32)}
# {'predictions': array([7.9962463], dtype=float32)}
# {'predictions': array([9.071418], dtype=float32)}
# {'predictions': array([8.186943], dtype=float32)}
# {'predictions': array([6.2638197], dtype=float32)}
# {'predictions': array([10.012582], dtype=float32)}
# {'predictions': array([9.468889], dtype=float32)}
# {'predictions': array([5.558119], dtype=float32)}
# {'predictions': array([4.5357943], dtype=float32)}
# {'predictions': array([10.002899], dtype=float32)}
# {'predictions': array([8.167849], dtype=float32)}
# {'predictions': array([10.110613], dtype=float32)}
# {'predictions': array([5.589864], dtype=float32)}
# {'predictions': array([7.1242], dtype=float32)}
# {'predictions': array([8.537548], dtype=float32)}
# {'predictions': array([4.9570847], dtype=float32)}
# {'predictions': array([6.2749343], dtype=float32)}
# {'predictions': array([6.5103583], dtype=float32)}
# {'predictions': array([8.445641], dtype=float32)}
# {'predictions': array([9.573786], dtype=float32)}
# {'predictions': array([8.612855], dtype=float32)}
# {'predictions': array([8.122794], dtype=float32)}
# {'predictions': array([9.104355], dtype=float32)}
# {'predictions': array([6.888559], dtype=float32)}
# {'predictions': array([9.492793], dtype=float32)}
# {'predictions': array([9.105257], dtype=float32)}
# {'predictions': array([7.645419], dtype=float32)}
# {'predictions': array([6.664757], dtype=float32)}
# {'predictions': array([5.9194956], dtype=float32)}
# {'predictions': array([8.834894], dtype=float32)}
# {'predictions': array([10.181683], dtype=float32)}
# {'predictions': array([8.356773], dtype=float32)}
# {'predictions': array([5.1271133], dtype=float32)}
# {'predictions': array([6.8455515], dtype=float32)}
# {'predictions': array([8.442285], dtype=float32)}
# {'predictions': array([4.3323646], dtype=float32)}
# {'predictions': array([8.19222], dtype=float32)}
# {'predictions': array([6.1033], dtype=float32)}
# {'predictions': array([5.4347887], dtype=float32)}
# {'predictions': array([6.082528], dtype=float32)}
# {'predictions': array([5.6287403], dtype=float32)}
# {'predictions': array([6.7725897], dtype=float32)}
# {'predictions': array([8.577402], dtype=float32)}
# {'predictions': array([6.6518292], dtype=float32)}
# {'predictions': array([5.988165], dtype=float32)}
# {'predictions': array([8.648413], dtype=float32)}
# {'predictions': array([5.5868173], dtype=float32)}
# {'predictions': array([6.8649945], dtype=float32)}
# {'predictions': array([4.726404], dtype=float32)}
# {'predictions': array([5.4633236], dtype=float32)}
# {'predictions': array([7.2896214], dtype=float32)}
# {'predictions': array([8.263244], dtype=float32)}
# {'predictions': array([10.105525], dtype=float32)}
# {'predictions': array([4.424359], dtype=float32)}
# {'predictions': array([6.599202], dtype=float32)}
# {'predictions': array([7.3513594], dtype=float32)}
# {'predictions': array([5.542666], dtype=float32)}
# {'predictions': array([7.783172], dtype=float32)}
# {'predictions': array([7.7383986], dtype=float32)}
# {'predictions': array([6.320479], dtype=float32)}
# {'predictions': array([11.015454], dtype=float32)}
# {'predictions': array([7.1152897], dtype=float32)}
# {'predictions': array([7.441719], dtype=float32)}
# {'predictions': array([6.8159122], dtype=float32)}
# {'predictions': array([5.4985347], dtype=float32)}
# {'predictions': array([8.301362], dtype=float32)}
# {'predictions': array([4.394657], dtype=float32)}
# {'predictions': array([6.0157022], dtype=float32)}
# {'predictions': array([7.690547], dtype=float32)}
# {'predictions': array([5.9290504], dtype=float32)}
# {'predictions': array([6.587518], dtype=float32)}
# {'predictions': array([5.3299575], dtype=float32)}
# {'predictions': array([10.168364], dtype=float32)}
# {'predictions': array([7.3413835], dtype=float32)}
# {'predictions': array([8.991349], dtype=float32)}
# {'predictions': array([7.401665], dtype=float32)}
# {'predictions': array([8.455622], dtype=float32)}
# {'predictions': array([7.7756314], dtype=float32)}
# {'predictions': array([6.3478746], dtype=float32)}
# {'predictions': array([10.103177], dtype=float32)}
# {'predictions': array([7.579968], dtype=float32)}
# {'predictions': array([8.771351], dtype=float32)}
# {'predictions': array([5.751135], dtype=float32)}
# {'predictions': array([9.17964], dtype=float32)}
# {'predictions': array([7.9852896], dtype=float32)}
# {'predictions': array([8.15379], dtype=float32)}
# {'predictions': array([5.3989296], dtype=float32)}
# {'predictions': array([6.802887], dtype=float32)}
# {'predictions': array([7.274901], dtype=float32)}
# {'predictions': array([9.438806], dtype=float32)}
# {'predictions': array([5.6110587], dtype=float32)}
# {'predictions': array([6.040928], dtype=float32)}
# {'predictions': array([7.841441], dtype=float32)}
# {'predictions': array([9.513455], dtype=float32)}
# {'predictions': array([7.362544], dtype=float32)}
# {'predictions': array([6.051482], dtype=float32)}
# {'predictions': array([7.827615], dtype=float32)}
# {'predictions': array([6.386147], dtype=float32)}
# {'predictions': array([9.856688], dtype=float32)}
# {'predictions': array([6.3544044], dtype=float32)}
# {'predictions': array([8.8443165], dtype=float32)}
# {'predictions': array([10.435352], dtype=float32)}
# {'predictions': array([7.273891], dtype=float32)}
# {'predictions': array([9.35624], dtype=float32)}
# {'predictions': array([4.306911], dtype=float32)}
# {'predictions': array([10.059938], dtype=float32)}
# {'predictions': array([5.4281764], dtype=float32)}
# {'predictions': array([4.772409], dtype=float32)}
# {'predictions': array([6.1124296], dtype=float32)}
# {'predictions': array([7.0540075], dtype=float32)}
# {'predictions': array([10.210104], dtype=float32)}
# {'predictions': array([7.2391863], dtype=float32)}
# {'predictions': array([6.461218], dtype=float32)}
# {'predictions': array([5.8538713], dtype=float32)}
# {'predictions': array([7.583564], dtype=float32)}
# {'predictions': array([8.826198], dtype=float32)}
# {'predictions': array([5.6172333], dtype=float32)}
# {'predictions': array([5.8300643], dtype=float32)}
# {'predictions': array([7.834198], dtype=float32)}
# {'predictions': array([5.2801523], dtype=float32)}
# {'predictions': array([6.951232], dtype=float32)}
# {'predictions': array([5.6416025], dtype=float32)}
# {'predictions': array([9.630432], dtype=float32)}
# {'predictions': array([6.3011756], dtype=float32)}
# {'predictions': array([7.5291157], dtype=float32)}
# {'predictions': array([8.640364], dtype=float32)}
# {'predictions': array([8.399868], dtype=float32)}
# {'predictions': array([10.008331], dtype=float32)}
# {'predictions': array([9.195393], dtype=float32)}
# {'predictions': array([8.904738], dtype=float32)}
# {'predictions': array([7.3249536], dtype=float32)}
# {'predictions': array([6.0573387], dtype=float32)}
# {'predictions': array([7.66353], dtype=float32)}
# {'predictions': array([6.4446588], dtype=float32)}
# {'predictions': array([6.1882124], dtype=float32)}
# {'predictions': array([8.335075], dtype=float32)}
# {'predictions': array([5.0749273], dtype=float32)}
# {'predictions': array([4.8505144], dtype=float32)}
# {'predictions': array([9.095531], dtype=float32)}
# {'predictions': array([8.104567], dtype=float32)}
# {'predictions': array([7.9838133], dtype=float32)}
# {'predictions': array([6.5748262], dtype=float32)}
# {'predictions': array([9.516978], dtype=float32)}
# {'predictions': array([9.946975], dtype=float32)}
# {'predictions': array([6.2316904], dtype=float32)}
# {'predictions': array([4.5185223], dtype=float32)}
# {'predictions': array([7.735821], dtype=float32)}
# {'predictions': array([8.986456], dtype=float32)}
# {'predictions': array([9.3844185], dtype=float32)}
# {'predictions': array([7.547429], dtype=float32)}
# {'predictions': array([10.933165], dtype=float32)}
# {'predictions': array([3.9136078], dtype=float32)}
# {'predictions': array([6.1547613], dtype=float32)}
# {'predictions': array([7.35392], dtype=float32)}
# {'predictions': array([6.6059628], dtype=float32)}
# {'predictions': array([6.046522], dtype=float32)}
# {'predictions': array([5.2130413], dtype=float32)}
# {'predictions': array([10.808392], dtype=float32)}
# {'predictions': array([6.907818], dtype=float32)}
# {'predictions': array([7.629239], dtype=float32)}
# {'predictions': array([5.4969373], dtype=float32)}
# {'predictions': array([9.32318], dtype=float32)}
# {'predictions': array([8.92534], dtype=float32)}
# {'predictions': array([7.133196], dtype=float32)}
# {'predictions': array([8.962702], dtype=float32)}
# {'predictions': array([7.750224], dtype=float32)}
# {'predictions': array([9.238182], dtype=float32)}
# {'predictions': array([8.917244], dtype=float32)}
# {'predictions': array([5.469253], dtype=float32)}
# {'predictions': array([7.575644], dtype=float32)}
# {'predictions': array([4.7556653], dtype=float32)}
# {'predictions': array([8.244319], dtype=float32)}
# {'predictions': array([6.529866], dtype=float32)}
# {'predictions': array([6.4948044], dtype=float32)}
# {'predictions': array([7.549385], dtype=float32)}
# {'predictions': array([8.504831], dtype=float32)}
# {'predictions': array([7.7168875], dtype=float32)}
# {'predictions': array([4.188612], dtype=float32)}
# {'predictions': array([5.9561563], dtype=float32)}
# {'predictions': array([3.855085], dtype=float32)}
# {'predictions': array([7.355056], dtype=float32)}
# {'predictions': array([9.881216], dtype=float32)}
# {'predictions': array([5.544264], dtype=float32)}
# {'predictions': array([8.621987], dtype=float32)}
# {'predictions': array([7.5085764], dtype=float32)}
# {'predictions': array([10.755309], dtype=float32)}
# {'predictions': array([9.001734], dtype=float32)}
# {'predictions': array([9.617606], dtype=float32)}
# {'predictions': array([7.7161427], dtype=float32)}
# {'predictions': array([8.754829], dtype=float32)}
# {'predictions': array([5.9703903], dtype=float32)}
# {'predictions': array([9.505181], dtype=float32)}
# {'predictions': array([6.535879], dtype=float32)}
# {'predictions': array([7.3498106], dtype=float32)}
# {'predictions': array([11.053854], dtype=float32)}
# {'predictions': array([9.608867], dtype=float32)}
# {'predictions': array([4.999222], dtype=float32)}
# {'predictions': array([8.221624], dtype=float32)}
# {'predictions': array([6.4771185], dtype=float32)}
# {'predictions': array([7.0140734], dtype=float32)}
# {'predictions': array([8.918556], dtype=float32)}
# {'predictions': array([7.7488804], dtype=float32)}
# {'predictions': array([5.5601034], dtype=float32)}
# {'predictions': array([9.106586], dtype=float32)}
# {'predictions': array([5.6568384], dtype=float32)}
# {'predictions': array([6.908125], dtype=float32)}
# {'predictions': array([5.7681437], dtype=float32)}
# {'predictions': array([9.19427], dtype=float32)}
# {'predictions': array([6.9773426], dtype=float32)}
# {'predictions': array([6.4354467], dtype=float32)}
# {'predictions': array([9.782651], dtype=float32)}
# {'predictions': array([4.650073], dtype=float32)}
# {'predictions': array([7.3683624], dtype=float32)}
# {'predictions': array([7.7989264], dtype=float32)}
# {'predictions': array([8.9926815], dtype=float32)}
# {'predictions': array([8.498067], dtype=float32)}
# {'predictions': array([9.432175], dtype=float32)}
# {'predictions': array([7.0149784], dtype=float32)}
# {'predictions': array([6.5696263], dtype=float32)}
# {'predictions': array([10.079006], dtype=float32)}
# {'predictions': array([7.032812], dtype=float32)}
# {'predictions': array([8.17096], dtype=float32)}
# {'predictions': array([9.793867], dtype=float32)}
# {'predictions': array([8.815918], dtype=float32)}
# {'predictions': array([10.954588], dtype=float32)}
# {'predictions': array([8.960083], dtype=float32)}
# {'predictions': array([8.7674465], dtype=float32)}
# {'predictions': array([8.557009], dtype=float32)}
# {'predictions': array([8.854786], dtype=float32)}
# {'predictions': array([6.8108096], dtype=float32)}
# {'predictions': array([6.8361235], dtype=float32)}
# {'predictions': array([9.7441845], dtype=float32)}
# {'predictions': array([8.994896], dtype=float32)}
# {'predictions': array([7.9545245], dtype=float32)}
# {'predictions': array([9.221828], dtype=float32)}
# {'predictions': array([5.398104], dtype=float32)}
# {'predictions': array([7.401184], dtype=float32)}
# {'predictions': array([8.973917], dtype=float32)}
# {'predictions': array([7.3157325], dtype=float32)}
# {'predictions': array([6.9097214], dtype=float32)}
# {'predictions': array([10.651254], dtype=float32)}
# {'predictions': array([6.388586], dtype=float32)}
# {'predictions': array([5.232779], dtype=float32)}
# {'predictions': array([6.322524], dtype=float32)}
# {'predictions': array([6.01075], dtype=float32)}
# {'predictions': array([5.084108], dtype=float32)}
# {'predictions': array([8.888142], dtype=float32)}
# {'predictions': array([8.006365], dtype=float32)}
# {'predictions': array([10.777072], dtype=float32)}
# {'predictions': array([5.141617], dtype=float32)}
# {'predictions': array([7.904404], dtype=float32)}
# {'predictions': array([6.8825016], dtype=float32)}
# {'predictions': array([7.3022556], dtype=float32)}
# {'predictions': array([7.687467], dtype=float32)}
# {'predictions': array([4.5536404], dtype=float32)}
# {'predictions': array([5.238315], dtype=float32)}
# {'predictions': array([4.221634], dtype=float32)}
# {'predictions': array([10.471317], dtype=float32)}
# {'predictions': array([6.6694937], dtype=float32)}
# {'predictions': array([8.490078], dtype=float32)}
# {'predictions': array([7.1232224], dtype=float32)}
# {'predictions': array([7.179727], dtype=float32)}
# {'predictions': array([5.8190384], dtype=float32)}
# {'predictions': array([7.972829], dtype=float32)}
# {'predictions': array([8.430636], dtype=float32)}
# {'predictions': array([6.8129864], dtype=float32)}
# {'predictions': array([7.11281], dtype=float32)}
# {'predictions': array([8.967163], dtype=float32)}
# {'predictions': array([5.8148384], dtype=float32)}
# {'predictions': array([9.134981], dtype=float32)}
# {'predictions': array([7.3144016], dtype=float32)}
# {'predictions': array([5.941205], dtype=float32)}
# {'predictions': array([3.9975178], dtype=float32)}
# {'predictions': array([8.226462], dtype=float32)}
# {'predictions': array([8.08182], dtype=float32)}
# {'predictions': array([8.8042755], dtype=float32)}
# {'predictions': array([6.5563817], dtype=float32)}
# {'predictions': array([4.8022213], dtype=float32)}
# {'predictions': array([7.868203], dtype=float32)}
# {'predictions': array([9.128332], dtype=float32)}
# {'predictions': array([9.618615], dtype=float32)}
# {'predictions': array([10.881657], dtype=float32)}
# {'predictions': array([6.9432087], dtype=float32)}
# {'predictions': array([7.8742766], dtype=float32)}
# {'predictions': array([7.106971], dtype=float32)}
# {'predictions': array([7.6119576], dtype=float32)}
# {'predictions': array([8.601082], dtype=float32)}
# {'predictions': array([7.5771656], dtype=float32)}
# {'predictions': array([7.647112], dtype=float32)}
# {'predictions': array([6.4098835], dtype=float32)}
# {'predictions': array([7.318471], dtype=float32)}
# {'predictions': array([6.287163], dtype=float32)}
# {'predictions': array([4.1412773], dtype=float32)}
# {'predictions': array([6.5985346], dtype=float32)}
# {'predictions': array([5.031379], dtype=float32)}
# {'predictions': array([6.7837543], dtype=float32)}
# {'predictions': array([9.4030285], dtype=float32)}
# {'predictions': array([7.6263905], dtype=float32)}
# {'predictions': array([7.9475374], dtype=float32)}
# {'predictions': array([10.866037], dtype=float32)}
# {'predictions': array([9.6919565], dtype=float32)}
# {'predictions': array([7.8432055], dtype=float32)}
# {'predictions': array([8.080127], dtype=float32)}
# {'predictions': array([7.954813], dtype=float32)}
# {'predictions': array([6.9686365], dtype=float32)}
# {'predictions': array([8.136133], dtype=float32)}
# {'predictions': array([8.062965], dtype=float32)}
# {'predictions': array([6.6953325], dtype=float32)}
# {'predictions': array([9.791943], dtype=float32)}
# {'predictions': array([7.0051947], dtype=float32)}
# {'predictions': array([9.245418], dtype=float32)}
# {'predictions': array([6.6066914], dtype=float32)}
# {'predictions': array([6.6898108], dtype=float32)}
# {'predictions': array([8.060777], dtype=float32)}
# {'predictions': array([7.4843593], dtype=float32)}
# {'predictions': array([7.654896], dtype=float32)}
# {'predictions': array([8.467138], dtype=float32)}
# {'predictions': array([6.669536], dtype=float32)}
# {'predictions': array([6.7160544], dtype=float32)}
# {'predictions': array([6.1682863], dtype=float32)}
# {'predictions': array([6.3675823], dtype=float32)}
# {'predictions': array([9.555297], dtype=float32)}
# {'predictions': array([9.634244], dtype=float32)}
# {'predictions': array([7.357358], dtype=float32)}
# {'predictions': array([5.065195], dtype=float32)}
# {'predictions': array([9.197182], dtype=float32)}
